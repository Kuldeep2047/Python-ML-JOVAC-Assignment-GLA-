# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
# TASK - 1

# %%
data = [25, 30, 35, 40, 45]
series = pd.Series(data, index=['A', 'B', 'C', 'D', 'E'])
print(series)
# Out:
# A    25
# B    30
# C    35
# D    40
# E    45
# dtype: int64

# %%
print('First three :\n',series.head(3))
# Out:
# First three :
#  A    25
# B    30
# C    35
# dtype: int64

# %%
mean = series.mean()
med = series.median()
std = series.std()

print("Mean :",mean)
print('Median :',med)
print("Standard Deviation ;",std)
# Out:
# Mean : 35.0
# Median : 35.0
# Standard Deviation ; 7.905694150420948

# %%
# TASK - 2

# %%
data = {
    'Name': ['Alice', 'Bob', 'Carol', 'David', 'Eve'],
    'Age': [20, 22, 19, 21, 20],
    'Gender': ['Female', 'Male', 'Female', 'Male', 'Female'],
    'Marks': [85, 78, 92, 74, 88]
}

df = pd.DataFrame(data)
df
# Out:
#     Name  Age  Gender  Marks
# 0  Alice   20  Female     85
# 1    Bob   22    Male     78
# 2  Carol   19  Female     92
# 3  David   21    Male     74
# 4    Eve   20  Female     88

# %%
print("First two row:\n")
df.head(2)
# Out:
# First two row:
#     Name  Age  Gender  Marks
# 0  Alice   20  Female     85
# 1    Bob   22    Male     78

# %%
print("Column Names:", df.columns.tolist())
print()
print("Data Types:\n", df.dtypes)
# Out:
# Column Names: ['Name', 'Age', 'Gender', 'Marks']
#
# Data Types:
#  Name      object
# Age        int64
# Gender    object
# Marks      int64
# dtype: object

# %%
print("Summary Statistics")
df.describe()
# Out:
# Summary Statistics
#              Age      Marks
# count   5.000000   5.000000
# mean   20.400000  83.400000
# std     1.140175   7.334848
# min    19.000000  74.000000
# 25%    20.000000  78.000000
# 50%    20.000000  85.000000
# 75%    21.000000  88.000000
# max    22.000000  92.000000

# %%
df['Passed'] = df['Marks'] >= 80
df
# Out:
#     Name  Age  Gender  Marks  Passed
# 0  Alice   20  Female     85    True
# 1    Bob   22    Male     78   False
# 2  Carol   19  Female     92    True
# 3  David   21    Male     74   False
# 4    Eve   20  Female     88    True

# %%
# TASK - 3

# %%
df = pd.DataFrame(data)
df
# Out:
#     Name  Age  Gender  Marks
# 0  Alice   20  Female     85
# 1    Bob   22    Male     78
# 2  Carol   19  Female     92
# 3  David   21    Male     74
# 4    Eve   20  Female     88

# %%
print("Name and Marks columns:")
df[['Name', 'Marks']]
# Out:
# Name and Marks columns:
#     Name  Marks
# 0  Alice     85
# 1    Bob     78
# 2  Carol     92
# 3  David     74
# 4    Eve     88

# %%
# Records where Marks > 80
fil_df = df[df['Marks'] > 80]
fil_df
# Out:
#     Name  Age  Gender  Marks
# 0  Alice   20  Female     85
# 2  Carol   19  Female     92
# 4    Eve   20  Female     88

# %%
# Display the record of the student with the highest marks
max_marks = df['Marks'].max()
student = df[df['Marks'] == max_marks]
student
# Out:
#     Name  Age  Gender  Marks
# 2  Carol   19  Female     92

# %%
# TASK - 4

# %%
df
# Out:
#     Name  Age  Gender  Marks
# 0  Alice   20  Female     85
# 1    Bob   22    Male     78
# 2  Carol   19  Female     92
# 3  David   21    Male     74
# 4    Eve   20  Female     88

# %%
df.loc[1, 'Marks'] = None
df.loc[4, 'Age'] = None

# %%
# Missing values in DataFrame:
df.isnull()
# Out:
#     Name    Age  Gender  Marks
# 0  False  False   False  False
# 1  False  False   False   True
# 2  False  False   False  False
# 3  False  False   False  False
# 4  False   True   False  False

# %%
# DataFrame after filling missing 'Marks' with mean:
marks_mean = df['Marks'].mean()
df['Marks'].fillna(marks_mean, inplace=True)
df
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_19340\3329177829.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Marks'].fillna(marks_mean, inplace=True)
#     Name   Age  Gender  Marks
# 0  Alice  20.0  Female  85.00
# 1    Bob  22.0    Male  84.75
# 2  Carol  19.0  Female  92.00
# 3  David  21.0    Male  74.00
# 4    Eve   NaN  Female  88.00

# %%
# Drop rows where 'Age' is missing
df.dropna(subset=['Age'])
# Out:
#     Name   Age  Gender  Marks
# 0  Alice  20.0  Female  85.00
# 1    Bob  22.0    Male  84.75
# 2  Carol  19.0  Female  92.00
# 3  David  21.0    Male  74.00

# %%
# TASK - 5

# %%
df
# Out:
#     Name   Age  Gender  Marks
# 0  Alice  20.0  Female  85.00
# 1    Bob  22.0    Male  84.75
# 2  Carol  19.0  Female  92.00
# 3  David  21.0    Male  74.00
# 4    Eve   NaN  Female  88.00

# %%
# Mean Age and Marks for each Gender
mean_stats = df.groupby('Gender')[['Age', 'Marks']].mean()
mean_stats
# Out:
#          Age      Marks
# Gender
# Female  19.5  88.333333
# Male    21.5  79.375000

# %%
# Number of students in each Gender group
c = df['Gender'].value_counts()
c
# Out:
# Gender
# Female    3
# Male      2
# Name: count, dtype: int64

# %%
# TASK - 6

# %%
data = {
    'Name': ['Alice', 'Bob', 'Carol', 'David', 'Eve'],
    'Age': [20, 22, 19, 21, None],
    'Gender': ['Female', 'Male', 'Female', 'Male', 'Female'],
    'Marks': [85, None, 92, 74, 88]
}
df = pd.DataFrame(data)
df
# Out:
#     Name   Age  Gender  Marks
# 0  Alice  20.0  Female   85.0
# 1    Bob  22.0    Male    NaN
# 2  Carol  19.0  Female   92.0
# 3  David  21.0    Male   74.0
# 4    Eve   NaN  Female   88.0

# %%
# Save to CSV
df.to_csv("students_data.csv", index=False)

# %%
# Read the CSV file into a new DataFrame
df_loaded = pd.read_csv("students_data.csv")
df_loaded
# Out:
#     Name   Age  Gender  Marks
# 0  Alice  20.0  Female   85.0
# 1    Bob  22.0    Male    NaN
# 2  Carol  19.0  Female   92.0
# 3  David  21.0    Male   74.0
# 4    Eve   NaN  Female   88.0

# %%
# first five rows
df_loaded.head(5)
# Out:
#     Name   Age  Gender  Marks
# 0  Alice  20.0  Female   85.0
# 1    Bob  22.0    Male    NaN
# 2  Carol  19.0  Female   92.0
# 3  David  21.0    Male   74.0
# 4    Eve   NaN  Female   88.0

# %%
# TASK - 7

# %%
df = pd.read_csv("Area_Population_Density_and_Population_2011_Census.csv")
df.columns = df.columns.str.strip()

df
# Out:
#           District  Geograpical Area (Sq.Kms)  Population Density      Male  \
# 0         Chikkodi                        851                 419    181619
# 1           Athani                       1554                 240    190310
# 2           Raibag                        952                 426    207142
# 3            Gokak                       1146                 348    200104
# 4          Hukkeri                        987                 405    200490
# ..             ...                        ...                 ...       ...
# 223       Shorapur                       1014                 249    126942
# 224  Gurumithakala                        697                 206     71320
# 225       Vadagera                        704                 156     55044
# 226       Hunisigi                        826                 194     81231
# 227    State Total                     191791                 319  30966657
#
#        Female     Total  Percentage Share to Total Population  Rank
# 0      174525    356144                                  7.45   6.0
# 1      182265    372575                                  7.80   5.0
# 2      198347    405489                                  8.48   2.0
# 3      198288    398392                                  8.34   4.0
# 4      198780    399270                                  8.35   3.0
# ..        ...       ...                                   ...   ...
# 223    125391    252333                                 21.00   3.0
# 224     71942    143262                                 12.00   5.0
# 225     54708    109752                                  9.00   3.0
# 226     78727    159958                                 14.00   4.0
# 227  30128640  61095297                                100.00   NaN
#
# [228 rows x 8 columns]

# %%
print("First 5 Rows of the Dataset:\n")
df.head()
# Out:
# First 5 Rows of the Dataset:
#    District  Geograpical Area (Sq.Kms)  Population Density    Male  Female  \
# 0  Chikkodi                        851                 419  181619  174525
# 1    Athani                       1554                 240  190310  182265
# 2    Raibag                        952                 426  207142  198347
# 3     Gokak                       1146                 348  200104  198288
# 4   Hukkeri                        987                 405  200490  198780
#
#     Total  Percentage Share to Total Population  Rank
# 0  356144                                  7.45   6.0
# 1  372575                                  7.80   5.0
# 2  405489                                  8.48   2.0
# 3  398392                                  8.34   4.0
# 4  399270                                  8.35   3.0

# %%
# Clean column names (remove leading/trailing spaces)
df.columns.str.strip()
# Out:
# Index(['District', 'Geograpical Area (Sq.Kms)', 'Population Density', 'Male',
#        'Female', 'Total', 'Percentage Share to Total Population', 'Rank'],
#       dtype='object')

# %%
print("Dataset Info:")
df.info()
# Out:
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 228 entries, 0 to 227
# Data columns (total 8 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   District                              228 non-null    object
#  1   Geograpical Area (Sq.Kms)             228 non-null    int64
#  2   Population Density                    228 non-null    int64
#  3   Male                                  228 non-null    int64
#  4   Female                                228 non-null    int64
#  5   Total                                 228 non-null    int64
#  6   Percentage Share to Total Population  228 non-null    float64
#  7   Rank                                  227 non-null    float64
# dtypes: float64(2), int64(5), object(1)
# memory usage: 14.4+ KB

# %%
print("Summary Statistics:")
df.describe(include='all')
# Out:
# Summary Statistics:
#         District  Geograpical Area (Sq.Kms)  Population Density          Male  \
# count        228                 228.000000          228.000000  2.280000e+02
# unique       228                        NaN                 NaN           NaN
# top     Chikkodi                        NaN                 NaN           NaN
# freq           1                        NaN                 NaN           NaN
# mean         NaN                1682.377193          326.399123  2.716373e+05
# std          NaN               12652.081507          378.260607  2.050760e+06
# min          NaN                 123.000000           28.000000  1.803000e+04
# 25%          NaN                 538.500000          186.000000  6.679200e+04
# 50%          NaN                 797.500000          249.000000  1.027085e+05
# 75%          NaN                1064.500000          352.500000  1.437400e+05
# max          NaN              191791.000000         5082.000000  3.096666e+07
#
#               Female         Total  Percentage Share to Total Population  \
# count   2.280000e+02  2.280000e+02                            228.000000
# unique           NaN           NaN                                   NaN
# top              NaN           NaN                                   NaN
# freq             NaN           NaN                                   NaN
# mean    2.642863e+05  5.359237e+05                             13.594474
# std     1.994551e+06  4.045298e+06                             10.277710
# min     1.756500e+04  3.564400e+04                              1.930000
# 25%     6.818700e+04  1.343270e+05                              7.435000
# 50%     1.022780e+05  2.064120e+05                             10.440000
# 75%     1.416150e+05  2.848725e+05                             17.185000
# max     3.012864e+07  6.109530e+07                            100.000000
#
#               Rank
# count   227.000000
# unique         NaN
# top            NaN
# freq           NaN
# mean      4.612335
# std       2.865638
# min       1.000000
# 25%       2.000000
# 50%       4.000000
# 75%       6.000000
# max      14.000000

# %%
# Missing Values in Each Column:
df.isnull().sum()
# Out:
# District                                0
# Geograpical Area (Sq.Kms)               0
# Population Density                      0
# Male                                    0
# Female                                  0
# Total                                   0
# Percentage Share to Total Population    0
# Rank                                    1
# dtype: int64

# %%
# Top 10 states by population density
top10 =df.sort_values(by='Population Density', ascending=False).head(10)
top10
# Out:
#                District  Geograpical Area (Sq.Kms)  Population Density  \
# 80      Hubballi Nagara                        142                5082
# 201              Mysuru                        797                1581
# 188           Mangalore                        618                1570
# 168           Yelahanka                        387                1286
# 166              Anekal                        530                 977
# 5              Belagavi                       1032                 928
# 134               Udupi                        310                 818
# 167      Bangalore-East                        172                 792
# 22   Rabakavi Banahatti                        351                 732
# 164   Bangalore (North)                        650                 725
#
#         Male   Female    Total  Percentage Share to Total Population  Rank
# 80    324793   320730   645523                                 34.96   1.0
# 201   645316   636452  1281768                                 42.71   1.0
# 188   439075   450151   889226                                 42.55   1.0
# 168   341725   307688   649413                                  4.92   4.0
# 166   282006   235569   517575                                  5.38   5.0
# 5     486704   470669   957373                                 20.03   1.0
# 134   124329   129346   253675                                 21.55   2.0
# 167   703462   629510  1332972                                 13.85   3.0
# 22    140665   137317   277982                                 14.71   2.0
# 164  2438383  2275047  4713430                                 50.81   1.0

# %%
df.columns = df.columns.str.strip()

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='Total', y='District', data=top10, hue='District', palette='rocket', legend=False)

plt.title('Top 10 Districts by Total Population')
plt.xlabel('Total Population')
plt.ylabel('District')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(data=df, x='Geograpical Area (Sq.Kms)', y='Population Density')
plt.title('Geographical Area vs Population Density')
plt.xlabel('Area (Sq.Kms)')
plt.ylabel('Population Density')
plt.tight_layout()
plt.show()
